# %%
import xinfer

xinfer.list_models()
# Out:
#                                      Available Models
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Implementation ┃ Model ID                                        ┃ Input --> Output    ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ timm           │ eva02_large_patch14_448.mim_m38m_ft_in22k_in1k  │ image --> class     │
# │ timm           │ eva02_large_patch14_448.mim_m38m_ft_in1k        │ image --> class     │
# │ timm           │ eva02_large_patch14_448.mim_in22k_ft_in22k_in1k │ image --> class     │
# │ timm           │ eva02_large_patch14_448.mim_in22k_ft_in1k       │ image --> class     │
# │ timm           │ eva02_base_patch14_448.mim_in22k_ft_in22k_in1k  │ image --> class     │
# │ timm           │ eva02_base_patch14_448.mim_in22k_ft_in1k        │ image --> class     │
# │ timm           │ eva02_small_patch14_336.mim_in22k_ft_in1k       │ image --> class     │
# │ timm           │ eva02_tiny_patch14_336.mim_in22k_ft_in1k        │ image --> class     │
# │ transformers   │ Salesforce/blip2-opt-6.7b-coco                  │ image-text --> text │
# │ transformers   │ Salesforce/blip2-flan-t5-xxl                    │ image-text --> text │
# │ transformers   │ Salesforce/blip2-opt-6.7b                       │ image-text --> text │
# │ transformers   │ Salesforce/blip2-opt-2.7b                       │ image-text --> text │
# │ transformers   │ vikhyatk/moondream2                             │ image-text --> text │
# │ ultralytics    │ yolov8x                                         │ image --> objects   │
# │ ultralytics    │ yolov8m                                         │ image --> objects   │
# │ ultralytics    │ yolov8l                                         │ image --> objects   │
# │ ultralytics    │ yolov8s                                         │ image --> objects   │
# │ ultralytics    │ yolov8n                                         │ image --> objects   │
# │ ultralytics    │ yolov10x                                        │ image --> objects   │
# │ ultralytics    │ yolov10m                                        │ image --> objects   │
# │ ...            │ ...                                             │ ...                 │
# │ ...            │ ...                                             │ ...                 │
# └────────────────┴─────────────────────────────────────────────────┴─────────────────────┘

# %%
model = xinfer.create_model("eva02_small_patch14_336.mim_in22k_ft_in1k", device="cuda", dtype="bfloat16")
# Out:
# 2024-10-15 10:50:17.880 | INFO     | xinfer.timm.timm_model:__init__:19 - Model: eva02_small_patch14_336.mim_in22k_ft_in1k
# 2024-10-15 10:50:17.881 | INFO     | xinfer.timm.timm_model:__init__:20 - Device: cuda
# 2024-10-15 10:50:17.882 | INFO     | xinfer.timm.timm_model:__init__:21 - Dtype: bfloat16
# 2024-10-15 10:50:17.882 | INFO     | xinfer.timm.timm_model:load_model:36 - Loading model: eva02_small_patch14_336.mim_in22k_ft_in1k

# %%
model.infer("https://ultralytics.com/images/bus.jpg", top_k=10, verbose=True)
# Out:
# AUTOTUNE convolution(1x3x336x336, 384x3x14x14)
#   convolution 0.0645 ms 100.0%
#   triton_convolution_4 0.1014 ms 63.6%
#   triton_convolution_6 0.1985 ms 32.5%
#   triton_convolution_1 0.2284 ms 28.3%
#   triton_convolution_3 0.2345 ms 27.5%
#   triton_convolution_5 0.2365 ms 27.3%
#   triton_convolution_0 0.2970 ms 21.7%
#   triton_convolution_2 0.4127 ms 15.6%
# SingleProcess AUTOTUNE takes 1.4648 seconds
# AUTOTUNE addmm(577x1152, 577x384, 384x1152)
#   triton_mm_7 0.0154 ms 100.0%
#   triton_mm_15 0.0172 ms 89.4%
#   triton_mm_12 0.0174 ms 88.2%
#   triton_mm_13 0.0184 ms 83.3%
#   triton_mm_8 0.0195 ms 78.9%
#   triton_mm_9 0.0195 ms 78.9%
#   triton_mm_11 0.0195 ms 78.9%
#   triton_mm_16 0.0195 ms 78.9%
#   triton_mm_17 0.0195 ms 78.9%
#   triton_mm_10 0.0205 ms 75.0%
# SingleProcess AUTOTUNE takes 1.6983 seconds
# AUTOTUNE mm(577x384, 384x384)
#   mm 0.0092 ms 100.0%
#   triton_mm_25 0.0092 ms 100.0%
#   triton_mm_27 0.0092 ms 100.0%
#   triton_mm_24 0.0102 ms 90.7%
#   triton_mm_28 0.0102 ms 90.0%
#   triton_mm_19 0.0113 ms 81.8%
#   triton_mm_20 0.0123 ms 75.0%
#   triton_mm_21 0.0123 ms 75.0%
#   triton_mm_22 0.0123 ms 75.0%
#   triton_mm_23 0.0123 ms 75.0%
# SingleProcess AUTOTUNE takes 1.5916 seconds
# AUTOTUNE mm(577x384, 384x2048)
#   triton_mm_32 0.0195 ms 100.0%
#   triton_mm_33 0.0195 ms 100.0%
#   triton_mm_35 0.0195 ms 100.0%
#   mm 0.0205 ms 95.0%
#   triton_mm_31 0.0205 ms 95.0%
#   triton_mm_34 0.0205 ms 95.0%
#   triton_mm_39 0.0205 ms 95.0%
#   triton_mm_38 0.0215 ms 90.5%
#   triton_mm_41 0.0215 ms 90.5%
#   triton_mm_36 0.0246 ms 79.2%
# SingleProcess AUTOTUNE takes 1.6006 seconds
# AUTOTUNE mm(577x1024, 1024x384)
#   mm 0.0152 ms 100.0%
#   triton_mm_51 0.0154 ms 99.0%
#   triton_mm_48 0.0174 ms 87.3%
#   triton_mm_49 0.0174 ms 87.3%
#   triton_mm_52 0.0174 ms 87.3%
#   triton_mm_43 0.0205 ms 74.2%
#   triton_mm_44 0.0225 ms 67.5%
#   triton_mm_45 0.0225 ms 67.5%
#   triton_mm_46 0.0246 ms 61.8%
#   triton_mm_47 0.0246 ms 61.8%
# SingleProcess AUTOTUNE takes 1.5811 seconds
# AUTOTUNE addmm(1x1000, 1x384, 384x1000)
#   triton_mm_589 0.0061 ms 100.0%
#   bias_addmm 0.0072 ms 85.7%
#   triton_mm_585 0.0072 ms 85.7%
#   triton_mm_586 0.0072 ms 85.7%
#   triton_mm_587 0.0072 ms 85.7%
#   triton_mm_591 0.0072 ms 85.7%
#   triton_mm_584 0.0082 ms 75.0%
#   addmm 0.0091 ms 67.3%
#   triton_mm_583 0.0092 ms 66.7%
#   triton_mm_588 0.0092 ms 66.7%
# SingleProcess AUTOTUNE takes 1.7056 seconds
# 2024-10-15 10:50:48.365 | INFO     | xinfer.timm.timm_model:infer:87 - Inference time: 28552.3136 ms
# 2024-10-15 10:50:48.366 | INFO     | xinfer.timm.timm_model:infer:88 - Device: cuda
# 2024-10-15 10:50:48.366 | INFO     | xinfer.timm.timm_model:infer:89 - Dtype: torch.bfloat16
# [{'class': 'trolleybus, trolley coach, trackless trolley',
#   'id': 874,
#   'confidence': 87.0},
#  {'class': 'streetcar, tram, tramcar, trolley, trolley car',
#   'id': 829,
#   'confidence': 3.59375},
#  {'class': 'minibus', 'id': 654, 'confidence': 2.3125},
#  {'class': 'passenger car, coach, carriage', 'id': 705, 'confidence': 0.6875},
#  {'class': 'amphibian, amphibious vehicle',
#   'id': 408,
#   'confidence': 0.1435546875},
#  {'class': 'school bus', 'id': 779, 'confidence': 0.130859375},
#  {'class': 'Loafer', 'id': 630, 'confidence': 0.1083984375},
#  {'class': 'traffic light, traffic signal, stoplight',
#   'id': 920,
#   'confidence': 0.08056640625},
#  {'class': 'street sign', 'id': 919, 'confidence': 0.06982421875},
#  {'class': 'fur coat', 'id': 568, 'confidence': 0.06689453125}]

# %%
model.infer_batch(["https://ultralytics.com/images/bus.jpg", "https://ultralytics.com/images/bus.jpg"], top_k=10)
# Out:
# AUTOTUNE convolution(2x3x336x336, 384x3x14x14)
#   convolution 0.0666 ms 100.0%
#   triton_convolution_599 0.1412 ms 47.1%
#   triton_convolution_601 0.1997 ms 33.3%
#   triton_convolution_596 0.2263 ms 29.4%
#   triton_convolution_600 0.2355 ms 28.3%
#   triton_convolution_598 0.2365 ms 28.1%
#   triton_convolution_595 0.2939 ms 22.6%
#   triton_convolution_597 0.6328 ms 10.5%
# SingleProcess AUTOTUNE takes 2.5186 seconds
# AUTOTUNE addmm(1154x1152, 1154x384, 384x1152)
#   triton_mm_602 0.0236 ms 100.0%
#   triton_mm_612 0.0246 ms 95.8%
#   triton_mm_610 0.0255 ms 92.5%
#   triton_mm_603 0.0266 ms 88.5%
#   triton_mm_607 0.0266 ms 88.5%
#   triton_mm_604 0.0267 ms 88.2%
#   triton_mm_605 0.0276 ms 85.2%
#   triton_mm_606 0.0276 ms 85.2%
#   triton_mm_608 0.0276 ms 85.2%
#   triton_mm_611 0.0338 ms 69.7%
# SingleProcess AUTOTUNE takes 3.2464 seconds
# AUTOTUNE mm(1154x384, 384x384)
#   triton_mm_614 0.0123 ms 100.0%
#   triton_mm_615 0.0123 ms 100.0%
#   triton_mm_616 0.0123 ms 100.0%
#   triton_mm_619 0.0124 ms 98.7%
#   mm 0.0133 ms 92.3%
#   triton_mm_617 0.0133 ms 92.3%
#   triton_mm_618 0.0133 ms 92.3%
#   triton_mm_620 0.0133 ms 92.3%
#   triton_mm_622 0.0133 ms 92.3%
#   triton_mm_623 0.0143 ms 85.7%
# SingleProcess AUTOTUNE takes 2.9544 seconds
# AUTOTUNE mm(1154x384, 384x2048)
#   triton_mm_626 0.0328 ms 100.0%
#   triton_mm_627 0.0328 ms 100.0%
#   triton_mm_628 0.0328 ms 100.0%
#   mm 0.0348 ms 94.1%
#   triton_mm_629 0.0348 ms 94.1%
#   triton_mm_630 0.0348 ms 94.1%
#   triton_mm_634 0.0348 ms 94.1%
#   triton_mm_636 0.0358 ms 91.4%
#   triton_mm_631 0.0399 ms 82.1%
#   triton_mm_633 0.0399 ms 82.1%
# SingleProcess AUTOTUNE takes 2.8957 seconds
# AUTOTUNE mm(1154x1024, 1024x384)
#   triton_mm_639 0.0225 ms 100.0%
#   triton_mm_640 0.0225 ms 100.0%
#   triton_mm_643 0.0236 ms 95.7%
#   triton_mm_644 0.0236 ms 95.7%
#   triton_mm_638 0.0236 ms 95.5%
#   mm 0.0244 ms 92.5%
#   triton_mm_641 0.0256 ms 88.0%
#   triton_mm_642 0.0256 ms 88.0%
#   triton_mm_646 0.0256 ms 88.0%
#   triton_mm_649 0.0309 ms 72.8%
# SingleProcess AUTOTUNE takes 3.0471 seconds
# AUTOTUNE addmm(2x1000, 2x384, 384x1000)
#   triton_mm_1184 0.0061 ms 100.0%
#   triton_mm_1182 0.0072 ms 85.7%
#   triton_mm_1186 0.0072 ms 85.7%
#   triton_mm_1181 0.0073 ms 84.6%
#   triton_mm_1183 0.0073 ms 84.2%
#   bias_addmm 0.0082 ms 75.0%
#   triton_mm_1179 0.0082 ms 75.0%
#   triton_mm_1180 0.0082 ms 75.0%
#   triton_mm_1187 0.0082 ms 75.0%
#   triton_mm_1178 0.0092 ms 66.7%
# SingleProcess AUTOTUNE takes 2.7154 seconds
# [[{'class': 'trolleybus, trolley coach, trackless trolley',
#    'id': 874,
#    'confidence': 87.0},
#   {'class': 'streetcar, tram, tramcar, trolley, trolley car',
#    'id': 829,
#    'confidence': 3.59375},
#   {'class': 'minibus', 'id': 654, 'confidence': 2.3125},
#   {'class': 'passenger car, coach, carriage', 'id': 705, 'confidence': 0.6875},
#   {'class': 'amphibian, amphibious vehicle',
#    'id': 408,
#    'confidence': 0.1435546875},
#   {'class': 'school bus', 'id': 779, 'confidence': 0.130859375},
#   {'class': 'Loafer', 'id': 630, 'confidence': 0.1083984375},
#   {'class': 'traffic light, traffic signal, stoplight',
#    'id': 920,
#    'confidence': 0.08056640625},
#   {'class': 'street sign', 'id': 919, 'confidence': 0.06982421875},
#   {'class': 'fur coat', 'id': 568, 'confidence': 0.06689453125}],
#  [{'class': 'trolleybus, trolley coach, trackless trolley',
#    'id': 874,
#    'confidence': 87.0},
#   {'class': 'streetcar, tram, tramcar, trolley, trolley car',
#    'id': 829,
#    'confidence': 3.59375},
#   {'class': 'minibus', 'id': 654, 'confidence': 2.3125},
#   {'class': 'passenger car, coach, carriage', 'id': 705, 'confidence': 0.6875},
#   {'class': 'amphibian, amphibious vehicle',
#    'id': 408,
#    'confidence': 0.1435546875},
#   {'class': 'school bus', 'id': 779, 'confidence': 0.130859375},
#   {'class': 'Loafer', 'id': 630, 'confidence': 0.1083984375},
#   {'class': 'traffic light, traffic signal, stoplight',
#    'id': 920,
#    'confidence': 0.08056640625},
#   {'class': 'street sign', 'id': 919, 'confidence': 0.06982421875},
#   {'class': 'fur coat', 'id': 568, 'confidence': 0.06689453125}]]

# %%
from xinfer.timm import TimmModel

model = TimmModel("resnet18", device="cuda", dtype="bfloat16")
model = xinfer.create_model(model)
# Out:
# 2024-10-15 10:51:26.685 | INFO     | xinfer.timm.timm_model:__init__:19 - Model: resnet18
# 2024-10-15 10:51:26.686 | INFO     | xinfer.timm.timm_model:__init__:20 - Device: cuda
# 2024-10-15 10:51:26.686 | INFO     | xinfer.timm.timm_model:__init__:21 - Dtype: bfloat16
# 2024-10-15 10:51:26.687 | INFO     | xinfer.timm.timm_model:load_model:36 - Loading model: resnet18

# %%
# model = xinfer.create_model("eva02_tiny_patch14_336.mim_in22k_ft_in1k")

result = model.infer("../assets/xinfer.jpg", top_k=10, verbose=True)
# Out:
# AUTOTUNE convolution(1x3x224x224, 64x3x7x7)
#   convolution 0.0297 ms 100.0%
#   triton_convolution_1194 0.0399 ms 74.4%
#   triton_convolution_1190 0.0512 ms 58.0%
#   triton_convolution_1193 0.0512 ms 58.0%
#   triton_convolution_1195 0.0707 ms 42.0%
#   triton_convolution_1192 0.0768 ms 38.7%
#   triton_convolution_1191 0.3000 ms 9.9%
# SingleProcess AUTOTUNE takes 1.9240 seconds
# AUTOTUNE convolution(1x64x56x56, 64x64x3x3)
#   convolution 0.0123 ms 100.0%
#   triton_convolution_1201 0.0174 ms 70.4%
#   triton_convolution_1200 0.0176 ms 69.5%
#   triton_convolution_1199 0.0227 ms 54.0%
#   triton_convolution_1196 0.0246 ms 49.9%
#   triton_convolution_1202 0.0317 ms 38.6%
#   triton_convolution_1197 0.0379 ms 32.3%
#   triton_convolution_1198 0.0891 ms 13.8%
# SingleProcess AUTOTUNE takes 2.0663 seconds
# AUTOTUNE convolution(1x64x56x56, 128x64x3x3)
#   convolution 0.0092 ms 100.0%
#   triton_convolution_1228 0.0174 ms 52.9%
#   triton_convolution_1229 0.0225 ms 40.9%
#   triton_convolution_1224 0.0276 ms 33.3%
#   triton_convolution_1230 0.0310 ms 29.8%
#   triton_convolution_1227 0.0317 ms 29.0%
#   triton_convolution_1225 0.0389 ms 23.7%
#   triton_convolution_1226 0.0983 ms 9.4%
# SingleProcess AUTOTUNE takes 2.2975 seconds
# AUTOTUNE convolution(1x128x28x28, 128x128x3x3)
#   convolution 0.0154 ms 100.0%
#   triton_convolution_1235 0.0276 ms 55.6%
#   triton_convolution_1236 0.0410 ms 37.5%
#   triton_convolution_1231 0.0522 ms 29.4%
#   triton_convolution_1234 0.0532 ms 28.8%
#   triton_convolution_1237 0.0563 ms 27.3%
#   triton_convolution_1232 0.0696 ms 22.1%
#   triton_convolution_1233 0.1649 ms 9.3%
# SingleProcess AUTOTUNE takes 2.1424 seconds
# AUTOTUNE convolution(1x64x56x56, 128x64x1x1)
#   triton_convolution_1242 0.0053 ms 100.0%
#   triton_convolution_1243 0.0061 ms 85.9%
#   triton_convolution_1238 0.0075 ms 70.8%
#   triton_convolution_1241 0.0082 ms 64.5%
#   triton_convolution_1244 0.0082 ms 64.5%
#   convolution 0.0092 ms 57.3%
#   triton_convolution_1239 0.0092 ms 57.3%
#   triton_convolution_1240 0.0113 ms 46.9%
# SingleProcess AUTOTUNE takes 1.9737 seconds
# AUTOTUNE convolution(1x128x28x28, 256x128x3x3)
#   convolution 0.0113 ms 100.0%
#   triton_convolution_1263 0.0266 ms 42.3%
#   triton_convolution_1264 0.0532 ms 21.2%
#   triton_convolution_1262 0.0543 ms 20.8%
#   triton_convolution_1265 0.0573 ms 19.6%
#   triton_convolution_1260 0.0727 ms 15.5%
#   triton_convolution_1259 0.0748 ms 15.1%
#   triton_convolution_1261 0.1004 ms 11.2%
# SingleProcess AUTOTUNE takes 2.2198 seconds
# AUTOTUNE convolution(1x256x14x14, 256x256x3x3)
#   convolution 0.0154 ms 100.0%
#   triton_convolution_1270 0.0502 ms 30.6%
#   triton_convolution_1268 0.0911 ms 16.9%
#   triton_convolution_1271 0.1004 ms 15.3%
#   triton_convolution_1269 0.1014 ms 15.2%
#   triton_convolution_1272 0.1075 ms 14.3%
#   triton_convolution_1267 0.1382 ms 11.1%
#   triton_convolution_1266 0.1434 ms 10.7%
# SingleProcess AUTOTUNE takes 2.1315 seconds
# AUTOTUNE convolution(1x128x28x28, 256x128x1x1)
#   convolution 0.0061 ms 100.0%
#   triton_convolution_1277 0.0061 ms 100.0%
#   triton_convolution_1279 0.0092 ms 66.7%
#   triton_convolution_1278 0.0102 ms 60.0%
#   triton_convolution_1276 0.0113 ms 54.5%
#   triton_convolution_1273 0.0123 ms 50.0%
#   triton_convolution_1274 0.0123 ms 50.0%
#   triton_convolution_1275 0.0123 ms 50.0%
# SingleProcess AUTOTUNE takes 2.1497 seconds
# AUTOTUNE convolution(1x256x14x14, 512x256x3x3)
#   convolution 0.0154 ms 100.0%
#   triton_convolution_1298 0.0491 ms 31.3%
#   triton_convolution_1299 0.1014 ms 15.2%
#   triton_convolution_1297 0.1024 ms 15.0%
#   triton_convolution_1300 0.1055 ms 14.6%
#   triton_convolution_1296 0.1199 ms 12.8%
#   triton_convolution_1295 0.1423 ms 10.8%
#   triton_convolution_1294 0.1464 ms 10.5%
# SingleProcess AUTOTUNE takes 2.1278 seconds
# AUTOTUNE convolution(1x512x7x7, 512x512x3x3)
#   convolution 0.0195 ms 100.0%
#   triton_convolution_1307 0.0952 ms 20.4%
#   triton_convolution_1305 0.0983 ms 19.8%
#   triton_convolution_1304 0.1382 ms 14.1%
#   triton_convolution_1303 0.1414 ms 13.8%
#   triton_convolution_1302 0.1915 ms 10.2%
#   triton_convolution_1306 0.1987 ms 9.8%
#   triton_convolution_1301 0.2939 ms 6.6%
# SingleProcess AUTOTUNE takes 1.8625 seconds
# AUTOTUNE convolution(1x256x14x14, 512x256x1x1)
#   convolution 0.0072 ms 100.0%
#   triton_convolution_1312 0.0092 ms 77.8%
#   triton_convolution_1310 0.0125 ms 57.3%
#   triton_convolution_1313 0.0143 ms 50.0%
#   triton_convolution_1314 0.0143 ms 50.0%
#   triton_convolution_1311 0.0164 ms 43.8%
#   triton_convolution_1309 0.0195 ms 36.8%
#   triton_convolution_1308 0.0205 ms 35.0%
# SingleProcess AUTOTUNE takes 2.0783 seconds
# AUTOTUNE addmm(1x1000, 1x512, 512x1000)
#   triton_mm_1335 0.0072 ms 100.0%
#   triton_mm_1332 0.0082 ms 87.5%
#   triton_mm_1333 0.0082 ms 87.5%
#   triton_mm_1337 0.0082 ms 87.5%
#   bias_addmm 0.0092 ms 77.8%
#   addmm 0.0092 ms 77.8%
#   triton_mm_1330 0.0092 ms 77.8%
#   triton_mm_1331 0.0092 ms 77.8%
#   triton_mm_1329 0.0102 ms 70.0%
#   triton_mm_1334 0.0102 ms 70.0%
# SingleProcess AUTOTUNE takes 2.7244 seconds
# 2024-10-15 10:52:01.122 | INFO     | xinfer.timm.timm_model:infer:87 - Inference time: 33516.6932 ms
# 2024-10-15 10:52:01.123 | INFO     | xinfer.timm.timm_model:infer:88 - Device: cuda
# 2024-10-15 10:52:01.123 | INFO     | xinfer.timm.timm_model:infer:89 - Dtype: torch.bfloat16

# %%
result
# Out:
# [{'class': 'analog clock', 'id': 409, 'confidence': 39.75},
#  {'class': 'wall clock', 'id': 892, 'confidence': 7.03125},
#  {'class': 'digital clock', 'id': 530, 'confidence': 4.40625},
#  {'class': 'hook, claw', 'id': 600, 'confidence': 1.2734375},
#  {'class': 'stopwatch, stop watch', 'id': 826, 'confidence': 1.2421875},
#  {'class': 'magnetic compass', 'id': 635, 'confidence': 1.1640625},
#  {'class': "loupe, jeweler's loupe", 'id': 633, 'confidence': 1.09375},
#  {'class': 'web site, website, internet site, site',
#   'id': 916,
#   'confidence': 0.96484375},
#  {'class': 'screw', 'id': 783, 'confidence': 0.90234375},
#  {'class': 'barometer', 'id': 426, 'confidence': 0.84765625}]
